# %%
 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
bank=pd.read_csv(r"C:\Users\HP\EDA\dataset\bank.csv",sep=";")
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank["job"].unique()
con1=bank["job"]=="unemployed"
con2=bank["marital"]=="married"
con3=con1 & con2
print(bank[con3])
# Out:
#       age         job  marital  education default  balance housing loan  \
# 0      30  unemployed  married    primary      no     1787      no   no
# 79     40  unemployed  married  secondary      no      219     yes   no
# 108    56  unemployed  married    primary      no     3391      no   no
# 239    51  unemployed  married   tertiary      no     1634     yes   no
# 307    38  unemployed  married    primary      no     1147     yes  yes
# ...   ...         ...      ...        ...     ...      ...     ...  ...
# 4217   38  unemployed  married   tertiary      no     2812     yes   no
# 4392   50  unemployed  married  secondary      no     3357      no   no
# 4410   36  unemployed  married  secondary      no      -35      no   no
# 4417   33  unemployed  married   tertiary      no      302     yes  yes
# 4448   44  unemployed  married  secondary      no      304     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
l=[]
for i in bank["job"].unique():
    con1 = bank["job"]==i
    con2 = bank["marital"]=="married"
    con3 = con1 & con2
    l.append(len(bank[con3]))
l
# Out:
# [75, 236, 557, 693, 127, 411, 132, 266, 10, 84, 176, 30]

# %%
df=pd.crosstab(bank["job"],bank["marital"])
df.plot(kind="bar")
# Out:
# <Axes: xlabel='job'>

# %%
pd.crosstab(bank["loan"],zip(bank["marital"],bank["education"],bank["housing"]))
# Out:
# col_0  (divorced, primary, no)  (divorced, primary, yes)  \
# loan
# no                          34                        36
# yes                          6                         3
#
# col_0  (divorced, secondary, no)  (divorced, secondary, yes)  \
# loan
# no                            81                         138
# yes                           25                          26
#
# col_0  (divorced, tertiary, no)  (divorced, tertiary, yes)  \
# loan
# no                           62                         63
# yes                          14                         16
#
# col_0  (divorced, unknown, no)  (divorced, unknown, yes)  \
# loan
# no                           8                        16
# yes                          0                         0
#
# col_0  (married, primary, no)  (married, primary, yes)  ...  \
# loan                                                    ...
# no                        197                      254  ...
# ...
